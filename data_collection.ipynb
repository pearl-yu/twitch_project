# %% [markdown]
# <a href="https://colab.research.google.com/github/pearl-yu/twitch_project/blob/main/data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dependent variable construction:
# Streaming time.

# %%
## Run this line if using Colab.
# !git clone https://github.com/pearl-yu/twitch_project
# %cd twitch_project/
# Out:
# Cloning into 'twitch_project'...
# remote: Enumerating objects: 113, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 113 (delta 57), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (113/113), 1.06 MiB | 9.79 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# /content/twitch_project

# %%
## So we can write the dataset to google drive (not github. need to upload to github manually for now.)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [raw]
# # ignore this cell for now
# from endpoint_call import *

# %%
import requests  # get the content from the API by using the get() method. json() method converts the API response to JSON format for easy handling.
import json   # to work with the returned json content from API.
import numpy as np
import pandas as pd

from pandas import json_normalize

import matplotlib.pyplot as plt

from datetime import datetime
import re

# %%
## Pearl's credentials
client_id = 'tamrylbvlu3wub4r8c5fddwsou246x'
client_secret= 'y4enh38kpiwkh7j00nqvv185ttsedw'

# Defining the URL to which we will make the request
url = 'https://id.twitch.tv/oauth2/token'
# Defining the parameters to be passed to the request
body = {
  'client_id'     : client_id,
  'client_secret' : client_secret,
  'grant_type'    : 'client_credentials'
}

access_code = requests.post(url, params=body) # Making a POST request to the URL to retrieve the access token
access_token = json.loads(access_code.text) #access token response is a JSON-encoded app access token

access_token = access_token['access_token']

# %% [markdown]
# With the sample:
# - Pull user ids by calling the https://dev.twitch.tv/docs/api/reference#get-users endpoint, specifying the login parameter.
# - Pull the video ids following this: https://github.com/btjmga/twitch-getallvods  (I didn't have the code to pull ALL the vids)
# - Pull the chatfiles of these videos. (using the downloader https://github.com/lay295/TwitchDownloader is easy. Check  https://github.com/Chaparro/rechat-dl and https://github.com/malciin/twitch-comments-downloader for code.)
# - Construct variables from the chatfile.
# - Call what other stuff?

# %%
# reference - read in multiple files: https://sparkbyexamples.com/pandas/pandas-read-multiple-csv-files/
# Import libraries
import glob

# Get CSV files list from a folder
path = './data/sample_by_growing_sullygnome'
csv_files = glob.glob(path + "/*.csv")

# Read each CSV file into DataFrame
df_list = (pd.read_csv(file) for file in csv_files) # This creates a list of dataframes
df   = pd.concat(df_list) # Concatenate all DataFrames

df = df.sample(frac=1) # shuffle the order of rows
print(df.shape)

df_en = df[df['Language'] == 'English'].reset_index()
#path = './data/sample_by_growing_sullygnome/Fastest growing Twitch streamers, past 30 days - SullyGnome (7).csv'
#df = pd.read_csv(path)

print(df_en.shape)
df_en.head()
# Out:
# (900, 13)
# (314, 14)
#    index  Unnamed: 0                                         Unnamed: 1  \
# 0     36        2937  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 1      9        1910  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 2     16        1917  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 3     69          70  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 4     15        2916  https://static-cdn.jtvnw.net/jtv_user_pictures...
#
#         Channel  Watch time (mins)  Stream time (mins)  Peak viewers  \
# 0      ImJoelll             163710                7425            61
# 1      SmallAnt            7587465                2685          5869
# 2  AussieAntics           27537990               14925          6147
# 3      NickEh30           40359090                8760         24095
# 4      lucidftt             467400                4455           305
#
#    Average viewers  Followers  Followers gained  Partnered  Mature Language  \
# 0               22       6100              3179      False   False  English
# 1             2825    1184219              4703       True   False  English
# 2             1845     858606              4675       True   False  English
# 3             4607    4135917             46897       True   False  English
# 4              104      21024              3196      False   False  English
#
#     Unnamed: 12
# 0      ImJoelll
# 1      SmallAnt
# 2  AussieAntics
# 3      NickEh30
# 4      lucidftt

# %% [markdown]
# # **A big thing! Maybe it's faster to download https://sullygnome.com/channels/30/followergrowth and pull out stream id, integrate that into the following data. There we have the content category information.**

# %%
def api_info(url = 'https://api.twitch.tv/helix/users?id=', key_series = df['Channel'], n = 5):
    '''
    url is the api URL
    key_series is a pandas series of the keys. check on the API reference page to see what should be the key
    n is the number of keys you wanna pull info from
    '''
    headers = {
            'Authorization' : 'Bearer '+str(access_token),
            'Client-Id' : client_id
        }

    temp_df = pd.DataFrame()
    for i in range(0,n) :
        temp_response = requests.get(url+str(key_series[i]), headers=headers)
        # Load the JSON
        temp_response_json = json.loads(temp_response.text)
        if list(temp_response_json.keys())[0] == 'error':
            continue
        else:
            temp_data = temp_response_json['data']
            temp_df_temp = pd.DataFrame.from_dict(json_normalize(temp_data), orient='columns')
        
            frames = [temp_df, temp_df_temp]
            temp_df = pd.concat(frames, ignore_index=True)
    
    print(temp_df.shape)
    print(temp_df.columns)
    
    return temp_df

# %%
## call the get_users end points to retrieve user id
user_df = api_info(url = 'https://api.twitch.tv/helix/users?login=',
         key_series = df_en['Channel'], 
         n = 100)

print(user_df.shape)
user_df.head()
# Out:
# (97, 10)
# Index(['id', 'login', 'display_name', 'type', 'broadcaster_type',
#        'description', 'profile_image_url', 'offline_image_url', 'view_count',
#        'created_at'],
#       dtype='object')
# (97, 10)
#           id         login  display_name type broadcaster_type  \
# 0   45302947     iitztimmy     iiTzTimmy               partner
# 1  580691169      plinkztv      PlinkzTV
# 2  826212800   pekggysoyed   pekggysoyed
# 3  229285909      akzontop      AkzOnTop             affiliate
# 4   35112592  general_mars  General_Mars             affiliate
#
#                                          description  \
# 0                              Where dreams are made
# 1     why you looking here lol.. follow or i sad  😢
# 2                         มือปืน ที่คมที่สุดในตอนนี้
# 3  The names AkzOnTop. WE GET LIT IN HEREEE HIT T...
# 4  I’ve been streaming on and off since at least ...
#
#                                    profile_image_url  \
# 0  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 1  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 2  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 3  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 4  https://static-cdn.jtvnw.net/jtv_user_pictures...
#
#                                    offline_image_url  view_count  \
# 0  https://static-cdn.jtvnw.net/jtv_user_pictures...    46151009
# 1                                                        1054382
# 2                                                              0
# 3                                                           3128
# 4  https://static-cdn.jtvnw.net/jtv_user_pictures...       79930
#
#              created_at
# 0  2013-06-28T04:15:32Z
# 1  2020-09-08T22:48:56Z
# 2  2022-09-17T11:50:28Z
# 3  2018-06-07T00:53:11Z
# 4  2012-08-20T02:32:21Z

# %%
## call the get_videos end points to retrieve all video ids of the users
video_df = api_info(url = 'https://api.twitch.tv/helix/videos?user_id=',
         key_series = user_df['id'], 
         n = len(user_df))

print(video_df.shape)
video_df.head()
# Out:
# (1595, 17)
# Index(['id', 'stream_id', 'user_id', 'user_login', 'user_name', 'title',
#        'description', 'created_at', 'published_at', 'url', 'thumbnail_url',
#        'viewable', 'view_count', 'language', 'type', 'duration',
#        'muted_segments'],
#       dtype='object')
# (1595, 17)
#            id    stream_id   user_id user_login  user_name  \
# 0  1619944979  41371583835  45302947  iitztimmy  iiTzTimmy
# 1  1619008572  41367685499  45302947  iitztimmy  iiTzTimmy
# 2  1618991112  41367613467  45302947  iitztimmy  iiTzTimmy
# 3  1617881723  41362847115  45302947  iitztimmy  iiTzTimmy
# 4  1617880267  40315785945  45302947  iitztimmy  iiTzTimmy
#
#                                                title description  \
# 0  Ultimate Challenge Gauntlet with softi @ Twitc...
# 1  Apex Twitch Rivals LIVE @ TwitchCon / Follow m...
# 2  Verizon Behind the Scenes. #ad/ Follow my soci...
# 3  Verizon Behind the Scenes. #ad/ Follow my soci...
# 4  Verizon Behind the Scenes. #ad/ Follow my soci...
#
#              created_at          published_at  \
# 0  2022-10-09T22:18:53Z  2022-10-09T22:18:53Z
# 1  2022-10-08T22:41:21Z  2022-10-08T22:41:21Z
# 2  2022-10-08T22:17:40Z  2022-10-08T22:17:40Z
# 3  2022-10-07T19:54:06Z  2022-10-07T19:54:06Z
# 4  2022-10-07T19:52:24Z  2022-10-07T19:52:24Z
#
#                                        url  \
# 0  https://www.twitch.tv/videos/1619944979
# 1  https://www.twitch.tv/videos/1619008572
# 2  https://www.twitch.tv/videos/1618991112
# 3  https://www.twitch.tv/videos/1617881723
# 4  https://www.twitch.tv/videos/1617880267
#
#                                        thumbnail_url viewable  view_count  \
# 0  https://static-cdn.jtvnw.net/cf_vods/d2nvs3185...   public      135401
# 1  https://static-cdn.jtvnw.net/cf_vods/d2nvs3185...   public      108462
# 2  https://static-cdn.jtvnw.net/cf_vods/d2nvs3185...   public       21690
# 3  https://static-cdn.jtvnw.net/cf_vods/d2nvs3185...   public        7383
# 4  https://static-cdn.jtvnw.net/cf_vods/d1m7jfoe9...   public        1527
#
#   language     type  duration muted_segments
# 0       en  archive  3h39m37s           None
# 1       en  archive   2h18m1s           None
# 2       en  archive    23m24s           None
# 3       en  archive     1m57s           None
# 4       en  archive       56s           None

# %%
# Some pre-processing of the video_df
video_df['created_at'] = pd.to_datetime(video_df['created_at']) 
video_df['duration_min'] = video_df['duration'].str.replace("h", '*60+').str.replace('m','*1+').str.replace('s','*(1/60)').apply(eval) # convert duration to numeric in minutes

# %%
# Get some simple statistics
print(video_df['created_at'].min(),video_df['created_at'].max())

video_df.groupby('user_id').agg({'id':'count',
                                 'created_at': [min,max],
                                 'duration_min':[min,max,'mean'],
                                 'view_count':'mean'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8a4234d23a07> in <module>
#       1 # Get some simple statistics
# ----> 2 print(video_df['created_at'].min(),video_df['created_at'].max())
#       3
#       4 video_df.groupby('user_id').agg({'id':'count',
#       5                                  'created_at': [min,max],
#
# NameError: name 'video_df' is not defined

# %%
user_temp = user_df[['id', 'broadcaster_type','description', 'profile_image_url', 'offline_image_url', 'created_at']]
user_temp.columns = ['user_id','broadcaster_type','broadcast_description','broadcaster_profile_image_url', 'broadcaster_offline_image_url', 'broadcaster_created_at']

video_df_merge= pd.merge(video_df, 
                         user_temp,  
                         how='left', left_on=['user_id'], right_on = ['user_id'])

print(video_df_merge.columns)
video_df_merge.head()
# Out:
# Index(['id', 'stream_id', 'user_id', 'user_login', 'user_name', 'title',
#        'description', 'created_at', 'published_at', 'url', 'thumbnail_url',
#        'viewable', 'view_count', 'language', 'type', 'duration',
#        'muted_segments', 'duration_min', 'broadcaster_type',
#        'broadcast_description', 'broadcaster_profile_image_url',
#        'broadcaster_offline_image_url', 'broadcaster_created_at'],
#       dtype='object')
#            id    stream_id   user_id user_login  user_name  \
# 0  1619944979  41371583835  45302947  iitztimmy  iiTzTimmy
# 1  1619008572  41367685499  45302947  iitztimmy  iiTzTimmy
# 2  1618991112  41367613467  45302947  iitztimmy  iiTzTimmy
# 3  1617881723  41362847115  45302947  iitztimmy  iiTzTimmy
# 4  1617880267  40315785945  45302947  iitztimmy  iiTzTimmy
#
#                                                title description  \
# 0  Ultimate Challenge Gauntlet with softi @ Twitc...
# 1  Apex Twitch Rivals LIVE @ TwitchCon / Follow m...
# 2  Verizon Behind the Scenes. #ad/ Follow my soci...
# 3  Verizon Behind the Scenes. #ad/ Follow my soci...
# 4  Verizon Behind the Scenes. #ad/ Follow my soci...
#
#                  created_at          published_at  \
# 0 2022-10-09 22:18:53+00:00  2022-10-09T22:18:53Z
# 1 2022-10-08 22:41:21+00:00  2022-10-08T22:41:21Z
# 2 2022-10-08 22:17:40+00:00  2022-10-08T22:17:40Z
# 3 2022-10-07 19:54:06+00:00  2022-10-07T19:54:06Z
# 4 2022-10-07 19:52:24+00:00  2022-10-07T19:52:24Z
#
#                                        url  ... language     type  duration  \
# 0  https://www.twitch.tv/videos/1619944979  ...       en  archive  3h39m37s
# 1  https://www.twitch.tv/videos/1619008572  ...       en  archive   2h18m1s
# 2  https://www.twitch.tv/videos/1618991112  ...       en  archive    23m24s
# 3  https://www.twitch.tv/videos/1617881723  ...       en  archive     1m57s
# 4  https://www.twitch.tv/videos/1617880267  ...       en  archive       56s
#
#   muted_segments duration_min broadcaster_type  broadcast_description  \
# 0           None   219.616667          partner  Where dreams are made
# 1           None   138.016667          partner  Where dreams are made
# 2           None    23.400000          partner  Where dreams are made
# 3           None     1.950000          partner  Where dreams are made
# 4           None     0.933333          partner  Where dreams are made
#
#                        broadcaster_profile_image_url  \
# 0  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 1  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 2  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 3  https://static-cdn.jtvnw.net/jtv_user_pictures...
# 4  https://static-cdn.jtvnw.net/jtv_user_pictures...
#
#                        broadcaster_offline_image_url broadcaster_created_at
# 0  https://static-cdn.jtvnw.net/jtv_user_pictures...   2013-06-28T04:15:32Z
# 1  https://static-cdn.jtvnw.net/jtv_user_pictures...   2013-06-28T04:15:32Z
# 2  https://static-cdn.jtvnw.net/jtv_user_pictures...   2013-06-28T04:15:32Z
# 3  https://static-cdn.jtvnw.net/jtv_user_pictures...   2013-06-28T04:15:32Z
# 4  https://static-cdn.jtvnw.net/jtv_user_pictures...   2013-06-28T04:15:32Z
#
# [5 rows x 23 columns]

# %%
video_df_merge.to_csv('video_df_merge.csv')

# %%
## retrieve chat files of these videos.
# https://pypi.org/project/chat-downloader/
# !pip install chat-downloader  # Need to install this everytime if you're using Colab.
from chat_downloader import ChatDownloader

# %%
## First we take a look at what data there is about the chats
url = video_df['url'][1]
chat = ChatDownloader().get_chat(url)       # create a generator
         # print the formatted message

# For each chat message, this is the full structure
next(chat)
# Out:
# {'message_id': '56dfa958-be91-4bd7-8679-979e1531f545',
#  'timestamp': 1665268893255000,
#  'time_in_seconds': 10.555,
#  'author': {'display_name': 'bobo_n',
#   'id': '566592468',
#   'name': 'bobo_n',
#   'type': 'user',
#   'bio': "I would like to remain unknown.Don't check whispers/dm often. ",
#   'created_at': 1597320910088820,
#   'images': [{'url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/3c4d4bfb-42e9-437d-ba41-caf351106950-profile_image-300x300.png',
#     'width': 300,
#     'height': 300,
#     'id': '300x300'},
#    {'url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/3c4d4bfb-42e9-437d-ba41-caf351106950-profile_image-70x70.png',
#     'width': 70,
#     'height': 70,
#     'id': '70x70'}],
#   'badges': [{'name': 'subscriber',
#     'version': 12,
#     'title': '1-Year Subscriber',
#     'description': '1-Year Subscriber',
#     'click_action': 'subscribe_to_channel',
#     'click_url': '',
#     'icons': [{'url': 'https://static-cdn.jtvnw.net/badges/v1/17c24133-f3e5-4b36-92f5-27dda8384523/1',
#       'width': 18,
#       'height': 18,
#       'id': '18x18'},
#      {'url': 'https://static-cdn.jtvnw.net/badges/v1/17c24133-f3e5-4b36-92f5-27dda8384523/2',
#       'width': 36,
#       'height': 36,
#       'id': '36x36'},
#      {'url': 'https://static-cdn.jtvnw.net/badges/v1/17c24133-f3e5-4b36-92f5-27dda8384523/3',
#       'width': 72,
#       'height': 72,
#       'id': '72x72'}],
#     'id': '17c24133-f3e5-4b36-92f5-27dda8384523'}],
#   'colour': '#FF7F50'},
#  'source': 'chat',
#  'state': 'published',
#  'message': 'We back',
#  'time_text': '0:10',
#  'message_type': 'text_message'}

# %%
## First we take a look at what data there is about the chats
url = video_df['url'][0]
chat = ChatDownloader().get_chat(url)       # create a generator
         # print the formatted message

# For each chat message, this is the full structure
next(chat)
# Out:
# {'message_id': '91ef235a-3a39-4102-88e7-3286b434b51a',
#  'timestamp': 1665353968134000,
#  'time_in_seconds': 34.434,
#  'author': {'display_name': 'Mar0n1_',
#   'id': '536714910',
#   'name': 'mar0n1_',
#   'type': 'user',
#   'bio': None,
#   'created_at': 1590687785273644,
#   'images': [{'url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/41780b5a-def8-11e9-94d9-784f43822e80-profile_image-300x300.png',
#     'width': 300,
#     'height': 300,
#     'id': '300x300'},
#    {'url': 'https://static-cdn.jtvnw.net/user-default-pictures-uv/41780b5a-def8-11e9-94d9-784f43822e80-profile_image-70x70.png',
#     'width': 70,
#     'height': 70,
#     'id': '70x70'}],
#   'colour': '#FF0000'},
#  'source': 'chat',
#  'state': 'published',
#  'message': 'yo first',
#  'time_text': '0:34',
#  'message_type': 'text_message'}

# %%
next(chat)
# Out:
# {'message_id': '741657a0-7d3d-4421-adc5-b113a8239428',
#  'timestamp': 1665353978988000,
#  'time_in_seconds': 45.288,
#  'author': {'display_name': 'StreamElements',
#   'id': '100135110',
#   'name': 'streamelements',
#   'type': 'user',
#   'bio': 'Elevate your content with www.StreamElements.com ✔️Free forever ✔️Legendary Service ✔️Trusted by the Best',
#   'created_at': 1440188714224473,
#   'images': [{'url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/streamelements-profile_image-a89b9d61499d365f-300x300.png',
#     'width': 300,
#     'height': 300,
#     'id': '300x300'},
#    {'url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/streamelements-profile_image-a89b9d61499d365f-70x70.png',
#     'width': 70,
#     'height': 70,
#     'id': '70x70'}],
#   'badges': [{'name': 'moderator',
#     'version': 1,
#     'title': 'Moderator',
#     'description': 'Moderator',
#     'click_action': 'none',
#     'click_url': '',
#     'icons': [{'url': 'https://static-cdn.jtvnw.net/badges/v1/3267646d-33f0-4b17-b3df-f923a41db1d0/1',
#       'width': 18,
#       'height': 18,
#       'id': '18x18'},
#      {'url': 'https://static-cdn.jtvnw.net/badges/v1/3267646d-33f0-4b17-b3df-f923a41db1d0/2',
#       'width': 36,
#       'height': 36,
#       'id': '36x36'},
#      {'url': 'https://static-cdn.jtvnw.net/badges/v1/3267646d-33f0-4b17-b3df-f923a41db1d0/3',
#       'width': 72,
#       'height': 72,
#       'id': '72x72'}],
#     'id': '3267646d-33f0-4b17-b3df-f923a41db1d0'},
#    {'name': 'subscriber',
#     'version': 3012,
#     'title': '1-Year Subscriber',
#     'description': '1-Year Subscriber',
#     'click_action': 'subscribe_to_channel',
#     'click_url': '',
#     'icons': [{'url': 'https://static-cdn.jtvnw.net/badges/v1/2a9828d9-3dc9-4e31-a6d8-c86037262936/1',
#       'width': 18,
#       'height': 18,
#       'id': '18x18'},
#      {'url': 'https://static-cdn.jtvnw.net/badges/v1/2a9828d9-3dc9-4e31-a6d8-c86037262936/2',
#       'width': 36,
#       'height': 36,
#       'id': '36x36'},
#      {'url': 'https://static-cdn.jtvnw.net/badges/v1/2a9828d9-3dc9-4e31-a6d8-c86037262936/3',
#       'width': 72,
#       'height': 72,
#       'id': '72x72'}],
#     'id': '2a9828d9-3dc9-4e31-a6d8-c86037262936'},
#    {'name': 'partner',
#     'version': 1,
#     'title': 'Verified',
#     'description': 'Verified',
#     'click_action': 'visit_url',
#     'click_url': 'https://blog.twitch.tv/2017/04/24/the-verified-badge-is-here-13381bc05735',
#     'icons': [{'url': 'https://static-cdn.jtvnw.net/badges/v1/d12a2e27-16f6-41d0-ab77-b780518f00a3/1',
#       'width': 18,
#       'height': 18,
#       'id': '18x18'},
#      {'url': 'https://static-cdn.jtvnw.net/badges/v1/d12a2e27-16f6-41d0-ab77-b780518f00a3/2',
#       'width': 36,
#       'height': 36,
#       'id': '36x36'},
#      {'url': 'https://static-cdn.jtvnw.net/badges/v1/d12a2e27-16f6-41d0-ab77-b780518f00a3/3',
#       'width': 72,
#       'height': 72,
#       'id': '72x72'}],
#     'id': 'd12a2e27-16f6-41d0-ab77-b780518f00a3'}],
#   'colour': '#5B99FF'},
#  'source': 'chat',
#  'state': 'published',
#  'message': 'shanenobi - iiTzCrosshair list for Valorant iitzThumbsUp → https://bit.ly/3Su3mKR !hudsight',
#  'emotes': [{'id': 'emotesv2_f1794ecf1c0345c98655087a730f9129',
#    'images': [{'url': 'https://static-cdn.jtvnw.net/emoticons/v2/emotesv2_f1794ecf1c0345c98655087a730f9129/default/light/1.0',
#      'width': 28,
#      'height': 28,
#      'id': '28x28-light'},
#     {'url': 'https://static-cdn.jtvnw.net/emoticons/v2/emotesv2_f1794ecf1c0345c98655087a730f9129/default/light/2.0',
#      'width': 56,
#      'height': 56,
#      'id': '56x56-light'},
#     {'url': 'https://static-cdn.jtvnw.net/emoticons/v2/emotesv2_f1794ecf1c0345c98655087a730f9129/default/light/3.0',
#      'width': 112,
#      'height': 112,
#      'id': '112x112-light'},
#     {'url': 'https://static-cdn.jtvnw.net/emoticons/v2/emotesv2_f1794ecf1c0345c98655087a730f9129/default/dark/1.0',
#      'width': 28,
#      'height': 28,
#      'id': '28x28-dark'},
#     {'url': 'https://static-cdn.jtvnw.net/emoticons/v2/emotesv2_f1794ecf1c0345c98655087a730f9129/default/dark/2.0',
#      'width': 56,
#      'height': 56,
#      'id': '56x56-dark'},
#     {'url': 'https://static-cdn.jtvnw.net/emoticons/v2/emotesv2_f1794ecf1c0345c98655087a730f9129/default/dark/3.0',
#      'width': 112,
#      'height': 112,
#      'id': '112x112-dark'}],
#    'name': 'iitzThumbsUp',
#    'locations': '44-55'}],
#  'time_text': '0:45',
#  'message_type': 'text_message'}

# %%
next(chat).keys()
# Out:
# dict_keys(['message_id', 'timestamp', 'time_in_seconds', 'author', 'source', 'state', 'message', 'time_text', 'message_type'])

# %%
next(chat)['author'].keys()
# Out:
# dict_keys(['display_name', 'id', 'name', 'type', 'bio', 'created_at', 'images', 'badges', 'colour'])

# %% [markdown]
# # **About the author, there're badges information that indicates if subscriber, if VIP, if partner streamer, etc. These should definitely be the controls. Also cheermotes and Emotes?**

# %%
# define function to get chat files.
import itertools

def get_chat(key_series = video_df['url'],n = 5, n_message_limit = 100):
  '''
    key_series is a pandas series of video urls.
    n is the number of videos you wanna pull chat from
    n_message_limit is the limit of messages you wanna pull from each video
    '''
  timestamp = []
  time_in_seconds = []
  messages = []
  author_id = []
  author_name = []
  author_bio = []
  #author_color = []
  video_url = []

  for i in range(0,n+1) :
    url = key_series[i]
    chat = ChatDownloader().get_chat(url)   
        
    top = itertools.islice(chat, n_message_limit)
    
    counter = len(messages)

    for message in top:     # iterate over messages
      video_url.append(url)                     
      timestamp.append(message['timestamp'])
      time_in_seconds.append(message['time_in_seconds'])
      author_id.append(message['author']['id'])
      author_name.append(message['author']['display_name'])
      author_bio.append(message['author']['bio'])
      #author_color.append(message['author']['colour'])
      messages.append(message['message'])
      
    print(i / n, url,len(messages)-counter)

  chat_df = pd.DataFrame(list(zip(video_url,timestamp,time_in_seconds,author_id,author_name,author_bio,messages)),
                         columns = ['video_url','timestamp','time_in_seconds','author_id','author_name','author_bio','messages'])
  
  return chat_df

# %%
video_df['duration_min'].describe()
# Out:
# count    1595.000000
# mean      305.147994
# std       356.858405
# min         0.150000
# 25%       137.133333
# 50%       240.500000
# 75%       385.183333
# max      2880.066667
# Name: duration_min, dtype: float64

# %%
df_temp = video_df[video_df['duration_min'] < video_df['duration_min'].quantile(0.50)].reset_index()

chat_df = get_chat(key_series = df_temp['url'],
                   n = 100,  # Just the first 100 videos. We'll need this for all the sample.
                   n_message_limit = 20000) ## max retries? Do we need to take those out manually? 30000 is safe tho.
# Out:
# 0.0 https://www.twitch.tv/videos/1619944979 9986
# 0.01 https://www.twitch.tv/videos/1619008572 3660
# 0.02 https://www.twitch.tv/videos/1618991112 817
# 0.03 https://www.twitch.tv/videos/1617881723 139
# 0.04 https://www.twitch.tv/videos/1617880267 40
# 0.05 https://www.twitch.tv/videos/1617874170 301
# 0.06 https://www.twitch.tv/videos/1617873084 13
# 0.07 https://www.twitch.tv/videos/1617870159 63
# 0.08 https://www.twitch.tv/videos/1617863430 430
# 0.09 https://www.twitch.tv/videos/1610408161 8064
# 0.1 https://www.twitch.tv/videos/1609724202 6857
# 0.11 https://www.twitch.tv/videos/1606719736 4477
# 0.12 https://www.twitch.tv/videos/1606649213 1686
# 0.13 https://www.twitch.tv/videos/1618720214 394
# 0.14 https://www.twitch.tv/videos/1618634928 327
# 0.15 https://www.twitch.tv/videos/1611038082 513
# 0.16 https://www.twitch.tv/videos/1608952075 335
# 0.17 https://www.twitch.tv/videos/1585705067 10
# 0.18 https://www.twitch.tv/videos/1584767361 60
# 0.19 https://www.twitch.tv/videos/1583649083 132
# 0.2 https://www.twitch.tv/videos/1582224366 3
# 0.21 https://www.twitch.tv/videos/1582178797 16
# 0.22 https://www.twitch.tv/videos/1579947206 77
# 0.23 https://www.twitch.tv/videos/1578324200 9
# 0.24 https://www.twitch.tv/videos/1578211985 68
# 0.25 https://www.twitch.tv/videos/1577479493 10
# 0.26 https://www.twitch.tv/videos/1575753603 0
# 0.27 https://www.twitch.tv/videos/1575346830 24
# 0.28 https://www.twitch.tv/videos/1573420701 15
# 0.29 https://www.twitch.tv/videos/1571805739 0
# 0.3 https://www.twitch.tv/videos/1608743384 0
# 0.31 https://www.twitch.tv/videos/1608008941 74
# 0.32 https://www.twitch.tv/videos/1606023442 1
# 0.33 https://www.twitch.tv/videos/1605943723 4
# 0.34 https://www.twitch.tv/videos/1604878671 111
# 0.35 https://www.twitch.tv/videos/1604165847 37
# 0.36 https://www.twitch.tv/videos/1604155977 0
# 0.37 https://www.twitch.tv/videos/1601701884 3
# 0.38 https://www.twitch.tv/videos/1610474447 2015
# 0.39 https://www.twitch.tv/videos/1610383580 2688
# 0.4 https://www.twitch.tv/videos/1610306079 1409
# 0.41 https://www.twitch.tv/videos/1610256098 1361
# 0.42 https://www.twitch.tv/videos/1610189267 1274
# 0.43 https://www.twitch.tv/videos/1609566577 2611
# 0.44 https://www.twitch.tv/videos/1609489717 1871
# 0.45 https://www.twitch.tv/videos/1609413513 1824
# 0.46 https://www.twitch.tv/videos/1609351390 1663
# 0.47 https://www.twitch.tv/videos/1609294840 1941
# 0.48 https://www.twitch.tv/videos/1604104930 0
# 0.49 https://www.twitch.tv/videos/1604104826 0
# 0.5 https://www.twitch.tv/videos/1604104878 0
# 0.51 https://www.twitch.tv/videos/1604098127 1191
# 0.52 https://www.twitch.tv/videos/1609245784 20000
# 0.53 https://www.twitch.tv/videos/1606964718 20000
# 0.54 https://www.twitch.tv/videos/1606861627 20000
# 0.55 https://www.twitch.tv/videos/1618941755 0
# 0.56 https://www.twitch.tv/videos/1607705926 0
# 0.57 https://www.twitch.tv/videos/1607057059 5
# 0.58 https://www.twitch.tv/videos/1607048978 0
# 0.59 https://www.twitch.tv/videos/1606986480 9
# 0.6 https://www.twitch.tv/videos/1606744058 1293
# 0.61 https://www.twitch.tv/videos/1605970076 485
# 0.62 https://www.twitch.tv/videos/1605886989 174
# 0.63 https://www.twitch.tv/videos/1590484650 768
# 0.64 https://www.twitch.tv/videos/1621583361 5986
# 0.65 https://www.twitch.tv/videos/1606061352 1473
# 0.66 https://www.twitch.tv/videos/1605572910 7002
# 0.67 https://www.twitch.tv/videos/1597668893 4623
# 0.68 https://www.twitch.tv/videos/1596471191 1984
# 0.69 https://www.twitch.tv/videos/1595921389 889
# 0.7 https://www.twitch.tv/videos/1617980407 3537
# 0.71 https://www.twitch.tv/videos/1610238890 1812
# 0.72 https://www.twitch.tv/videos/1607634101 2161
# 0.73 https://www.twitch.tv/videos/1604733184 2023
# 0.74 https://www.twitch.tv/videos/1013713136 1
# 0.75 https://www.twitch.tv/videos/1621692363 9327
# 0.76 https://www.twitch.tv/videos/1610656682 14482
# 0.77 https://www.twitch.tv/videos/1621428019 566
# 0.78 https://www.twitch.tv/videos/1621315606 848
# 0.79 https://www.twitch.tv/videos/1621305264 761
# 0.8 https://www.twitch.tv/videos/1619945189 19577
# 0.81 https://www.twitch.tv/videos/1610608136 1050
# 0.82 https://www.twitch.tv/videos/1608980830 886
# 0.83 https://www.twitch.tv/videos/1608965243 1957
# 0.84 https://www.twitch.tv/videos/1608568971 1685
# 0.85 https://www.twitch.tv/videos/1608567312 1116
# 0.86 https://www.twitch.tv/videos/1608526950 3664
# 0.87 https://www.twitch.tv/videos/1608476153 4198
# 0.88 https://www.twitch.tv/videos/1606577606 375
# 0.89 https://www.twitch.tv/videos/1606561421 948
# 0.9 https://www.twitch.tv/videos/1606457076 1169
# 0.91 https://www.twitch.tv/videos/1605033075 1684
# 0.92 https://www.twitch.tv/videos/1604458780 988
# 0.93 https://www.twitch.tv/videos/1602660242 973
# 0.94 https://www.twitch.tv/videos/1598015150 753
# 0.95 https://www.twitch.tv/videos/1595352118 1182
# 0.96 https://www.twitch.tv/videos/1594415722 1117
# 0.97 https://www.twitch.tv/videos/1592408289 613
# 0.98 https://www.twitch.tv/videos/1592319276 1419
# 0.99 https://www.twitch.tv/videos/1591613035 1255
# 1.0 https://www.twitch.tv/videos/1591561792 785

# %%
print(chat_df.shape)
print(chat_df.columns)
chat_df.head(5)
# Out:
# (226207, 7)
# Index(['video_url', 'timestamp', 'time_in_seconds', 'author_id', 'author_name',
#        'author_bio', 'messages'],
#       dtype='object')
#                                  video_url         timestamp  time_in_seconds  \
# 0  https://www.twitch.tv/videos/1619944979  1665353968134000           34.434
# 1  https://www.twitch.tv/videos/1619944979  1665353970195000           36.495
# 2  https://www.twitch.tv/videos/1619944979  1665353976374000           42.674
# 3  https://www.twitch.tv/videos/1619944979  1665353978426000           44.726
# 4  https://www.twitch.tv/videos/1619944979  1665353978792000           45.092
#
#    author_id      author_name  \
# 0  536714910          Mar0n1_
# 1   39378978            Azkii
# 2  821199354   itzBaMofficial
# 3  519136869  youngmoneybandz
# 4  477382692        shanenobi
#
#                                           author_bio          messages
# 0                                               None          yo first
# 1  Hello, I am Azkii. Proud member of the Toad Sq...  Have good steam!
# 2                      I play Valorant at the moment                hi
# 3                                          hey nerd              yoooo
# 4                                               None        !crosshair

# %%
chat_df.to_csv('chat_df.csv')

# %%
# Well, you can even click on the url. That's neat.
chat_df.groupby('video_url')['messages'].count().describe()
# Out:
# count       91.000000
# mean      2485.791209
# std       4476.312375
# min          1.000000
# 25%        135.500000
# 50%        988.000000
# 75%       1970.500000
# max      20000.000000
# Name: messages, dtype: float64

# %% [markdown]
# # **Ignore the code down below**

# %%
## First we take a look at what data there is about the chats
url = video_df['url'][1]
chat = ChatDownloader().get_chat(url)       # create a generator
         # print the formatted message

# For each chat message, this is the full structure
# next(chat)['author']['badges']

pd.DataFrame.from_dict(json_normalize(next(chat)), orient='columns')
# Out:
#                              message_id         timestamp  time_in_seconds  \
# 0  56dfa958-be91-4bd7-8679-979e1531f545  1665268893255000           10.555
#
#   source      state  message time_text  message_type author.display_name  \
# 0   chat  published  We back      0:10  text_message              bobo_n
#
#    author.id author.name author.type  \
# 0  566592468      bobo_n        user
#
#                                           author.bio  author.created_at  \
# 0  I would like to remain unknown.Don't check whi...   1597320910088820
#
#                                        author.images  \
# 0  [{'url': 'https://static-cdn.jtvnw.net/jtv_use...
#
#                                        author.badges author.colour
# 0  [{'name': 'subscriber', 'version': 12, 'title'...       #FF7F50

# %%
# define function to get chat files.
import itertools

def get_chat(key_series = video_df['url'],n = 5, n_message_limit = 100):
  '''
    key_series is a pandas series of video urls.
    n is the number of videos you wanna pull chat from
    n_message_limit is the limit of messages you wanna pull from each video
    '''
  temp_df = pd.DataFrame()
  for i in range(0,n) :
    url = key_series[i]
    chat = ChatDownloader().get_chat(url)   
        
    top = itertools.islice(chat, n_message_limit)
    
    for message in top:     # iterate over messages
      temp_df_temp = pd.DataFrame.from_dict(json_normalize(next(chat)), orient='columns')

      frames = [temp_df, temp_df_temp]
      temp_df = pd.concat(frames, ignore_index=True)
  
  return temp_df

# %%
chat_df = get_chat(key_series = video_df['url'],n = 2, n_message_limit = 5000)

print(chat_df.shape)
print(chat_df.columns)
chat_df.head(5)
# Out:
# (6823, 18)
#                              message_id         timestamp  time_in_seconds  \
# 0  0067de3a-3127-48e6-b2e8-706a67cfc81e  1665353970195000           36.495
# 1  7fdd1f1d-846b-4999-ae1a-d147a4e48503  1665353978426000           44.726
# 2  741657a0-7d3d-4421-adc5-b113a8239428  1665353978988000           45.288
# 3  b774da23-2eb2-4a0d-8408-f396d29e3c8a  1665353982651000           48.951
# 4  7631c35a-da75-4a16-a668-919cd6876181  1665353984845000           51.145
#
#   source      state                                            message  \
# 0   chat  published                                   Have good steam!
# 1   chat  published                                              yoooo
# 2   chat  published  shanenobi - iiTzCrosshair list for Valorant ii...
# 3   chat  published                                   yooooooooooooooo
# 4   chat  published                                             hi Tim
#
#   time_text  message_type author.display_name  author.id      author.name  \
# 0      0:36  text_message               Azkii   39378978            azkii
# 1      0:44  text_message     youngmoneybandz  519136869  youngmoneybandz
# 2      0:45  text_message      StreamElements  100135110   streamelements
# 3      0:48  text_message        acechopper13  505849553     acechopper13
# 4      0:51  text_message        Zed_Hennydog  428976858     zed_hennydog
#
#   author.type                                         author.bio  \
# 0        user  Hello, I am Azkii. Proud member of the Toad Sq...
# 1        user                                          hey nerd
# 2        user  Elevate your content with www.StreamElements.c...
# 3        user  I'm just going to do gaming and nothing but ga...
# 4        user                          Together we thunder 🇿🇲🇳🇿🌍
#
#    author.created_at                                      author.images  \
# 0   1358318766728854  [{'url': 'https://static-cdn.jtvnw.net/jtv_use...
# 1   1587643311316222  [{'url': 'https://static-cdn.jtvnw.net/jtv_use...
# 2   1440188714224473  [{'url': 'https://static-cdn.jtvnw.net/jtv_use...
# 3   1585541399427960  [{'url': 'https://static-cdn.jtvnw.net/user-de...
# 4   1554805481749155  [{'url': 'https://static-cdn.jtvnw.net/jtv_use...
#
#                                        author.badges author.colour  \
# 0  [{'name': 'premium', 'version': 1, 'title': 'P...       #008000
# 1  [{'name': 'subscriber', 'version': 6, 'title':...       #00FF7F
# 2  [{'name': 'moderator', 'version': 1, 'title': ...       #5B99FF
# 3  [{'name': 'premium', 'version': 1, 'title': 'P...       #2E8B57
# 4  [{'name': 'premium', 'version': 1, 'title': 'P...       #0000FF
#
#                                               emotes
# 0                                                NaN
# 1                                                NaN
# 2  [{'id': 'emotesv2_f1794ecf1c0345c98655087a730f...
# 3                                                NaN
# 4                                                NaN

# %%
# This is a demo of one streamer, 5 messages. 
## Now what do we want to put in a dataframe? 
url = video_df['url'][1]
chat = ChatDownloader().get_chat(url)   

timestamp = []
time_in_seconds = []
messages = []
author_display_name = []
# author_id = []
## Let's hold off the badges and emotes. Those are multi-levels. But they'll be super helpful!!

import itertools

top5 = itertools.islice(chat, 5)

for message in top5:                        # iterate over messages    
    timestamp.append(message['timestamp'])
    time_in_seconds.append(message['time_in_seconds'])
    messages.append(message['message'])
    author_display_name.append(message['author']['display_name'])
    ## better way to flatten. 
    ## can be zipped to a function

#for message in chat:                        # iterate over messages. It's not json!! It's just a dict
#    print(json.dumps(message, indent = 4, sort_keys=True))

chat_df = pd.DataFrame(list(zip(timestamp,time_in_seconds,messages,author_display_name)),
                       columns = ['timestamp','time_in_seconds','messages','author_display_name'])

chat_df.head()
## There're emotes!
# Out:
#           timestamp  time_in_seconds  \
# 0  1665286892922000           14.222
# 1  1665286915688000           36.988
# 2  1665286956005000           77.305
# 3  1665286976686000           97.986
# 4  1665286982791000          104.091
#
#                                             messages author_display_name
# 0                        chin shane sort dla piscine          stephanokc
# 1                  bye la bonne soireee jvous aiment         NurseScraby
# 2                             eille salut les boys !          stephanokc
# 3  Salut la! Jva prob encore cornifler demain si ...            ReactHD9
# 4                 oublie pas de temercier l'academie          stephanokc

# %%
chat_df = get_chat(key_series = video_df['url'],n = 5, n_message_limit = 100000)

print(chat_df.shape)
chat_df.head(10)
# Out:
# (1198, 5)
#                                  video_url         timestamp  time_in_seconds  \
# 0  https://www.twitch.tv/videos/1619335587  1665298566706000          293.006
# 1  https://www.twitch.tv/videos/1619335587  1665298566890000          293.190
# 2  https://www.twitch.tv/videos/1619335587  1665298567013000          293.313
# 3  https://www.twitch.tv/videos/1619335587  1665298816474000          542.774
# 4  https://www.twitch.tv/videos/1619335587  1665298975363000          701.663
# 5  https://www.twitch.tv/videos/1619335587  1665299000653000          726.953
# 6  https://www.twitch.tv/videos/1619335587  1665299006146000          732.446
# 7  https://www.twitch.tv/videos/1619335587  1665299128101000          854.401
# 8  https://www.twitch.tv/videos/1619335587  1665299165171000          891.471
# 9  https://www.twitch.tv/videos/1619335587  1665299257301000          983.601
#
#                                             messages author_display_name
# 0    fergyf1HYPE fergyf1HYPE fergyf1HYPE fergyf1HYPE         FergyFergTV
# 1    fergyf1HYPE fergyf1HYPE fergyf1HYPE fergyf1HYPE         FergyFergTV
# 2    fergyf1HYPE fergyf1HYPE fergyf1HYPE fergyf1HYPE         FergyFergTV
# 3           What can I serve you? "!drinks" to order        L3_Bartender
# 4                                              allo!            leGlitch
# 5  pas pire j't'encore réveillé mais pas pour lon...            leGlitch
# 6                                  aaaaahhhh poutine            leGlitch
# 7  jsuis bleu une débarque en bécique a beu ding ...            leGlitch
# 8                                juste pour la toune            leGlitch
# 9  je game pas avec mes cuisses donc drille mes c...            leGlitch

# %%
# Well, you can even click on the url. That's neat.
chat_df.groupby('video_url')['messages'].count()
# Out:
# video_url
# https://www.twitch.tv/videos/1618617417      5
# https://www.twitch.tv/videos/1618629121    144
# https://www.twitch.tv/videos/1618770779    366
# https://www.twitch.tv/videos/1618936117    224
# https://www.twitch.tv/videos/1619238405     10
# https://www.twitch.tv/videos/1619335587    449
# Name: messages, dtype: int64

# %% [markdown]
# Now, we need to extract variables from the chat, merge to video_df.

# %%
 = pd.merge(video_df, temp,  how='left', left_on=['video_url'], right_on = ['video_url'])

# %% [markdown]
# Parse

# %%
# No need for this anymore.
## parse chat file
def get_chat_dataframe(file):
    data = []
    with open(file, 'r', encoding='utf-8') as f:
        lines = f.read().split('\n')
        for line in lines:
            #print(line)
            
            time_logged = line.split('UTC')[0][1:].strip()
            #time_logged = datetime.strptime(time_logged,'%Y-%m-%d-%H:%M:%S')
            #print(time_logged)
            
            username_message = line.split(']')[1:]
            username_message = '—'.join(username_message).strip()
            #print(username_message)
            try:
                temp = username_message.split(":")
                username = temp[0]
                message = temp[1]
            except IndexError:
                username = temp[0]
                message = '-'
            #print(username)
            #print(message)
            
            d = {'dt': time_logged,
                 'username': username,
                 'message': message
                    }
            data.append(d)
            
    return pd.DataFrame().from_records(data)

# %%
## This is an example
chat_df = get_chat_dataframe('[1-21-22] Mongraal - Winning Duo Cash Cup With FaZe BL GUILD Flikk (Webcam Mic) - Chat.txt')

chat_df.head()

# %% [markdown]
# Cleaning and preprocessing

# %%
# Custom STOPWORDS removal -- Need to think about this.Could use the cloud as below 
from texthero import stopwords
default_stopwords = stopwords.DEFAULT
custom_stopwords = default_stopwords.union(set(['yo','play',"twitch","make", "use", "thank", "content", "good", "use",
                                                "think", "need", "harrisheller", "like", "stream",
                                               "kekw","catjam","tim","timthetatman","tatkevinh",
                                               "wipz","docspin","pog","tatlove","lol","lul","omegalul",
                                               "biblethump","clap","tathypers","pepeja","kappa","tattopd","ppsmoke",
                                               "pepelaugh","gopackgo","gachihyper","tatkevinh", "wipz",
                                               "pausechamp","yep","lmao","jack","lulw","monkaw","kreygasm",
                                               "pepega","peped","foxsalt","pogchamp","xqcn","get","back",
                                               "tattuff","tatfat","tatpumpkin","lmao","sadge","sippy",
                                               "pogu","poggers","consolecd","widepeepohappy","pogu","tategg2",
                                               "modcheck","timmy","tathmm","tats","got","com","babyrage",
                                               "xqcp","tatw","pokiw","know", "thats","pepocd","tatafk",
                                               "4weird","tatkkevin", "tatblanket","tatglam","tategg1","wutface",
                                               "blobdance", "kapp","tatbruh","kappapride","facebaby","xqc",
                                               "xqcm","bora","hyperclap","tatlit","5head","gachibass", "go", "ur",
                                                "yes","going","would","im","oh","dez","taty","tk","u","sg", "dont",
                                                "hey","hf","look","anita","anitaheart","leeper","anitahey",
                                                "anitadab","anitadoubt","anitahands", "anitalul","anitapog","anitasword",
                                                "anitaprime","anitafeels","residentsleeper","anitapride","anital",
                                                "anitabiscuit", "thing","widepeeposad","anitahype","among", "lesbianpride",
                                                "heyguys","seemsgood","notlikethis","hi","also","much","yeah",
                                               ])) ## Add as per requirement
# data = hero.remove_stopwords(data, default_stopwords)
chat_df_clean = hero.remove_stopwords(chat_df_temp, custom_stopwords)
